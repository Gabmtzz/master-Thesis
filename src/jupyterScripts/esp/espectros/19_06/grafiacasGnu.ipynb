# %%
plot "ESPECTRO1_2F.txt"  w linespoints t "1"
replot "ESPECTRO1_2F_2.txt" w linespoints t "2"

# %%
plot "ESPECTRO1_2F_200mT.txt" u 1:2 w linespoints t "1"
replot "ESPECTRO1_2F_2_200mT.txt" w linespoints t "2"

# %%
plot "ESPECTRO1_F_2.txt" w linespoints t "2"
replot "ESPECTRO1_F_3.txt" w linespoints t "2"

# %%
plot "ESPECTRO1_F_200mT.txt" w linespoints t "2"
replot "ESPECTRO1_F_2_200mT.txt" w linespoints t "2"

# %% [markdown]
# # graficas promedio con y sin campo

# %%
set xlabel "long. onda (nm)"
set ylabel "intenidad (U.A.)"
plot "datKerr" u 1:2 w linespoints t "f"
replot "datKerr" u 1:3 w linespoints t "f:200mT"

# %%
plot "datKerr" u 1:4 w linespoints t "2f"
replot "datKerr" u 1:5 w linespoints t "2f:200mT"

# %% [markdown]
# # Datos con campo

# %%
set termoption enhanced
set xlabel "longitud de onda ({/Symbol l})"
set ylabel "rotacion (rad)"
plot "datKerrCorr.txt" u 1:2 w linespoints t "{/Symbol q}_k"
replot "datKerrCorr.txt" u 1:3 w linespoints t "{/Symbol h}_k"

# %% [markdown]
# # datos sin campo

# %%
plot "datKerrCorr.txt" u 1:4 w linespoints t "{/Symbol q}_k"
replot "datKerrCorr.txt" u 1:5 w linespoints t "{/Symbol h}_k"

# %% [markdown]
# # Resta

# %%
plot "datKerrCorr.txt" u 1:($2-$4) w linespoints t "{/Symbol q}_k"
replot "datKerrCorr.txt" u 1:($3-$5) w linespoints t "{/Symbol h}_k"

# %%
plot [800:900]"datKerrCorr.txt" u 1:($4-$2) w linespoints t "{/Symbol q}_k"
replot [800:900] "datKerrCorr.txt" u 1:($5-$3) w linespoints t "{/Symbol h}_k"

# %% [markdown]
# # Sin campo

# %%
plot [800:900] "datKerrCorr.txt" u 1:4 w linespoints t "{/Symbol q}_k"
replot [800:900] "datKerrCorr.txt" u 1:5 w linespoints t "{/Symbol h}_k"

# %% [markdown]
# # Con campo

# %%
plot [800:900] "datKerrCorr.txt" u 1:2 w linespoints t "{/Symbol q}_k"
replot [800:900] "datKerrCorr.txt" u 1:3 w linespoints t "{/Symbol h}_k"

# %%
plot [840:900] "datKerrCorr.txt" u 1:2 w linespoints t "{/Symbol q}_k campo"
replot [840:900] "datKerrCorr.txt" u 1:3 w linespoints t "{/Symbol h}_k campo"
replot [840:900] "datKerrCorr.txt" u 1:4 w linespoints t "{/Symbol q}_k"
replot [840:900] "datKerrCorr.txt" u 1:5 w linespoints t "{/Symbol h}_k"
