# %%
plot "ESPECTRO1_F.txt" w linespoints notitle
replot "ESPECTRO1_F_2.txt" w linespoints notitle
replot "ESPECTRO1_F_3.txt" w linespoints notitle

# %%
plot "ESPECTRO1_2F.txt" w linespoints notitle
replot "ESPECTRO1_2F_2.txt" w linespoints notitle
